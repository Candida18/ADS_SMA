# %% [markdown]
# <a href="https://colab.research.google.com/github/Candida18/ADS_SMA/blob/main/2.%20Data%20Collection%20(YouTube_Web_Scraping).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### <b>Name: Candida Noronha<br/>
# ### <b>Class: BE COMPS B<br/>
# ### <b>Roll No.: 8960
# ### <b>Experiment 2 - YouTube Web Scraping

# %% [markdown]
# Steps:
# **Get API Key** - Go to the *Google Cloud console • (h.ÜuZL.nn.åQle.clQu1gQQgleumL) and sign in with your Google Account
#
#
# **Click the project drop-down menu** in the top bar and select or create the project you want to use.
#
#
# **Click the hamburger** menu in the top left and select APIs & Services >Select Youtube Data V3 API> Credentials.
#
#
# **Click the Create credential**s button and select API key.
#
# **The API key** will be displayed in a pop-up window. You can click the RESTRICT KEY button to restrict the API keys usage, such as by IP address or referrer.
#
#
# **Click the COPY** button to copy the API key to your clipboard.
#
# You can use the API key in your application to access the Google Cloud APIs. Be sure to keep the API key confidential, as it can be used to access your Google Cloud resources.

# %%
import requests

# %%
video_id = "jpqV3dzYOgk"

# %%
api_key = "AIzaSyCF1Wp0ypPrX0RT78KdZ7t8mS4K6LJ9QuY"

# %%
# Retrieve video information
video_info_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={video_id}&key={api_key}"
video_info_response = requests.get(video_info_url)
video_info_data = video_info_response.json()

# %%
video_info_data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'JF2tJ4_tVOBu0AB5Th6CwcsjAi4',
#  'items': [{'kind': 'youtube#video',
#    'etag': '70HRLB1QlTW9-wsyi18ztChaXSg',
#    'id': 'jpqV3dzYOgk',
#    'snippet': {'publishedAt': '2016-11-24T21:05:41Z',
#     'channelId': 'UCX0X2q2VgfN2l2VLSBUGOIQ',
#     'title': 'Zootopia - Try Everything (Lyrics, Shakira)',
#     'description': "Guys! Wanna hear more motivational songs? Please check out my good friend's channel, Mistr Rice! I'm collabing with him to create some awesome music that acknowledges issues such as mental health, toxic relationships, and more! https://www.youtube.com/channel/UCNkxB99qwMrkF3JWiqJ1sdw\n\nI do not own this song. All content belongs to Disney and its affiliates.",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/jpqV3dzYOgk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/jpqV3dzYOgk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
# ...

# %%
# Retrieve video compnts
comments_url = f"https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={video_id}&key={api_key}"
comments_response= requests.get(comments_url)
comments_data = comments_response.json()

# %%
comments_data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'Q8Vs_aXH_telLtOIFB8SPB46XB8',
#  'nextPageToken': 'QURTSl9pMU9OdmZCU1NBc3F6cnFKdmJ3S1JHbVZ3VXdPc195eDZZVGxWVmJKTGVobjdOeHYzdnhBM0RaZzhWanJEZDFUYTZFRkJWblBrUHdseUMwbFBmX3ZQb3g5eFd4RVE=',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'Ygw8xL7sn97zSbgZYBl8dRNJfzY',
#    'id': 'UgxrcMADTP-ieDgTJ7F4AaABAg',
#    'snippet': {'videoId': 'jpqV3dzYOgk',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'VtsTizdzI-mwE2adVflC7nSYr_A',
#      'id': 'UgxrcMADTP-ieDgTJ7F4AaABAg',
#      'snippet': {'videoId': 'jpqV3dzYOgk',
# ...

# %%
# Extract the carnents
comments = [item["snippet"]["topLevelComment"]["snippet"]["textOriginal"] for item in comments_data["items"]]

# %%
 print(comments)
# Out:
# ["Guys! Wanna hear more motivational songs? Please check out my good friend's channel, Mistr Rice! I'm collabing with him to create some awesome music that acknowledges issues such as mental health, toxic relationships, and more! https://www.youtube.com/channel/UCNkxB99qwMrkF3JWiqJ1sdw", '8', 'Min to', 'giving elementary school sm', 'I still like zootopia', "I'm so down.. sometimes we come last but we did our best.", 'Mac and cheese. Seriously?', "I love you. You can hate me. Heaven is yours, take it. I leave. I don’t need heaven. It's yours. He can burn me in hell. I embraced hell, i accept it. Dazzal isn’t my fear anymore.", 'I have to sing this for my school compense song', 'A assmess', 'I am learning this song at school because we’re doing', 'bro I danced to this song in 1st grade a every long time ago it just reminded me for the best past I had', 'Sharmaila b', 'So sad are you okay', '😲', 'cool', 'I remember singing this back in my primary school assemblys', 'Ricywcrxzvcxztljiod
# ...

# %%
from textblob import TextBlob

# %%
def get_comment_sentiment(comment):
  analysis = TextBlob(comment)
  if analysis.sentiment.polarity > 0:
    return "Positive"
  elif analysis.sentiment.polarity == 0:
    return "neutral"
  else:
    return "negative"

# %%
comment_list = []
sentiment_list = []
for comment in comments:
  sentiment = get_comment_sentiment(comment)
  comment_list.append(comment)
  sentiment_list.append(sentiment)
  print(f"{comment} : {sentiment}")
# Out:
# Guys! Wanna hear more motivational songs? Please check out my good friend's channel, Mistr Rice! I'm collabing with him to create some awesome music that acknowledges issues such as mental health, toxic relationships, and more! https://www.youtube.com/channel/UCNkxB99qwMrkF3JWiqJ1sdw : Positive
# 8 : neutral
# Min to : neutral
# giving elementary school sm : Positive
# I still like zootopia : neutral
# I'm so down.. sometimes we come last but we did our best. : Positive
# Mac and cheese. Seriously? : negative
# I love you. You can hate me. Heaven is yours, take it. I leave. I don’t need heaven. It's yours. He can burn me in hell. I embraced hell, i accept it. Dazzal isn’t my fear anymore. : negative
# I have to sing this for my school compense song : neutral
# A assmess : neutral
# I am learning this song at school because we’re doing : neutral
# bro I danced to this song in 1st grade a every long time ago it just reminded me for the best past I had : Positive
# ...

# %%
import pandas as pd

# %%
sentiment_df = pd.DataFrame({"Comments": comment_list,"Sentiment": sentiment_list})

# %%
sentiment_df.head()
# Out:
#                                             Comments Sentiment
# 0  Guys! Wanna hear more motivational songs? Plea...  Positive
# 1                                                  8   neutral
# 2                                             Min to   neutral
# 3                        giving elementary school sm  Positive
# 4                              I still like zootopia   neutral

# %%
sentiment_df.to_csv("YouTube_Comments_Sentiment.csv")

# %%
# !pip install boilerpipe3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from boilerpipe.extract import Extractor
# URL="https://www.amazon.in/s?k=grass+mat+for+baby&crid=3FKEPQH8TQDJ1&sprefix=grass+mat+for+baby%2Caps%2C211&ref=nb_sb_noss_1"
URL="https://www.amazon.in/s?k=titan+watch&crid=32JIDZ2082ZAS&sprefix=titan+watch%2Caps%2C258&ref=nb_sb_noss_1"
extrcator=Extractor(extractor='ArticleExtractor',url=URL)
print(extrcator.getText())
# Out:
# Get it by Wednesday, February 8
# FREE Delivery by Amazon
# Only 2 left in stock.
# 4+ star styles
# Shop coveted styles with many reviews
# Titan

# %%
# !pip install feedparser
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import feedparser

# %%
FEED_URL="http://feeds.feedburner.com/oreilly/radar/atom"
fp=feedparser.parse(FEED_URL)
for e in fp.entries:
  print(e.title)
  print(e.links[0].href)
  print(e.content[0].value)
# Out:
# Automating the Automators: Shift Change in the Robot Factory
# https://www.oreilly.com/radar/automating-the-automators-shift-change-in-the-robot-factory/
# <p>What would you say is the job of a software developer? A layperson, an entry-level developer, or even someone who hires developers will tell you that job is to … well … <em>write software.</em> Pretty simple.</p>
#
#
#
# <p>An experienced practitioner will tell you something very different. They&#8217;d say that the job <em>involves</em> writing some software, sure. But deep down it&#8217;s about the <em>purpose</em> of software. Figuring out what kinds of problems are amenable to automation through code. Knowing what to build, and sometimes what not to build because it won&#8217;t provide value.</p>
#
#
#
# <p>They may even summarize it as: &#8220;my job is to spot <code>for()</code> loops and <code>if/then</code> statements in the wild.&#8221;</p>
#
#
#
# ...
